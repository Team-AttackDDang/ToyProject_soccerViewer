# %%
##### ragnar 
# jupyter notebook test
import pandas as pd 
df = pd.read_table('../data/gameRecord.txt', sep=',', header=None, names=['날짜', '장소','상대팀','점수','결과'])


# df['장소']

no_stadium = ' 구장없음'
no_stadium_remove = df[df['장소'].str.contains(no_stadium)].index
df.drop(no_stadium_remove, inplace=True)
data = df
data = data.dropna()
data.style.hide_index()
# Out:
# C:\Users\mystpark\AppData\Local\Temp\ipykernel_7456\2356063792.py:14: FutureWarning: this method is deprecated in favour of `Styler.hide(axis='index')`
#   data.style.hide_index()
# <style type="text/css">
# </style>
# <table id="T_84512">
#   <thead>
#     <tr>
#       <th id="T_84512_level0_col0" class="col_heading level0 col0" >날짜</th>
#       <th id="T_84512_level0_col1" class="col_heading level0 col1" >장소</th>
#       <th id="T_84512_level0_col2" class="col_heading level0 col2" >상대팀</th>
#       <th id="T_84512_level0_col3" class="col_heading level0 col3" >점수</th>
#       <th id="T_84512_level0_col4" class="col_heading level0 col4" >결과</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_84512_row0_col0" class="data row0 col0" >2022년 08월 05일(금)</td>
#       <td id="T_84512_row0_col1" class="data row0 col1" > 동탄여울공원</td>
#       <td id="T_84512_row0_col2" class="data row0 col2" > 해적단FC</td>
#       <td id="T_84512_row0_col3" class="data row0 col3" > 5대4</td>
#       <td id="T_84512_row0_col4" class="data row0 col4" > 패</td>
#     </tr>
#     <tr>
#       <td id="T_84512_row1_col0" class="data row1 col0" >2022년 07월 02일(토)</td>
#       <td id="T_84512_row1_col1" class="data row1 col1" > 기흥레스피아</td>
#       <td id="T_84512_row1_col2" class="data row1 col2" > 아미FC</td>
#       <td id="T_84512_row1_col3" class="data row1 col3" > 8대4</td>
#       <td id="T_84512_row1_col4" class="data row1 col4" > 승</td>
#     </tr>
#     <tr>
#       <td id="T_84512_row2_col0" class="data row2 col0" >2022년 07월 09일(토)</td>
#       <td id="T_84512_row2_col1" class="data row2 col1" > 기흥레스피아</td>
#       <td id="T_84512_row2_col2" class="data row2 col2" > BD99FC</td>
#       <td id="T_84512_row2_col3" class="data row2 col3" > 4대3</td>
#       <td id="T_84512_row2_col4" class="data row2 col4" > 패</td>
#     </tr>
#     <tr>
#       <td id="T_84512_row3_col0" class="data row3 col0" >2022년 07월 23일(토)</td>
#       <td id="T_84512_row3_col1" class="data row3 col1" > 기흥레스피아</td>
#       <td id="T_84512_row3_col2" class="data row3 col2" > 도미너스FC</td>
#       <td id="T_84512_row3_col3" class="data row3 col3" > 6대4</td>
#       <td id="T_84512_row3_col4" class="data row3 col4" > 승</td>
#     </tr>
#     <tr>
#       <td id="T_84512_row4_col0" class="data row4 col0" >2022년 06월 04일(토)</td>
#       <td id="T_84512_row4_col1" class="data row4 col1" > 기흥레스피아</td>
#       <td id="T_84512_row4_col2" class="data row4 col2" > 개발FC</td>
#       <td id="T_84512_row4_col3" class="data row4 col3" > 4대2</td>
#       <td id="T_84512_row4_col4" class="data row4 col4" > 패</td>
#     </tr>
#     <tr>
#       <td id="T_84512_row5_col0" class="data row5 col0" >2022년 06월 18일(토)</td>
#       <td id="T_84512_row5_col1" class="data row5 col1" > 기흥레스피아</td>
#       <td id="T_84512_row5_col2" class="data row5 col2" > YSI FC</td>
#       <td id="T_84512_row5_col3" class="data row5 col3" > 7대2</td>
#       <td id="T_84512_row5_col4" class="data row5 col4" > 승</td>
#     </tr>
#     <tr>
#       <td id="T_84512_row6_col0" class="data row6 col0" >2022년 06월 25일(토)</td>
#       <td id="T_84512_row6_col1" class="data row6 col1" > 기흥레스피아</td>
#       <td id="T_84512_row6_col2" class="data row6 col2" > 빌드어스FC</td>
#       <td id="T_84512_row6_col3" class="data row6 col3" > 8대5</td>
#       <td id="T_84512_row6_col4" class="data row6 col4" > 승</td>
#     </tr>
#     <tr>
#       <td id="T_84512_row7_col0" class="data row7 col0" >2022년 05월 07일(토)</td>
#       <td id="T_84512_row7_col1" class="data row7 col1" > 기흥레스피아</td>
#       <td id="T_84512_row7_col2" class="data row7 col2" > 위원FC</td>
#       <td id="T_84512_row7_col3" class="data row7 col3" > 8대4</td>
#       <td id="T_84512_row7_col4" class="data row7 col4" > 승</td>
#     </tr>
#     <tr>
#       <td id="T_84512_row8_col0" class="data row8 col0" >2022년 05월 14일(토)</td>
#       <td id="T_84512_row8_col1" class="data row8 col1" > 기흥레스피아</td>
#       <td id="T_84512_row8_col2" class="data row8 col2" > 비틀즈FC</td>
#       <td id="T_84512_row8_col3" class="data row8 col3" > 4대4</td>
#       <td id="T_84512_row8_col4" class="data row8 col4" > 무</td>
#     </tr>
#     <tr>
#       <td id="T_84512_row9_col0" class="data row9 col0" >2022년 05월 21일(토)</td>
#       <td id="T_84512_row9_col1" class="data row9 col1" > 동탄여울공원</td>
#       <td id="T_84512_row9_col2" class="data row9 col2" > DS FC</td>
#       <td id="T_84512_row9_col3" class="data row9 col3" > 7대1</td>
#       <td id="T_84512_row9_col4" class="data row9 col4" > 승</td>
#     </tr>
#     <tr>
#       <td id="T_84512_row10_col0" class="data row10 col0" >2022년 05월 28일(토)</td>
#       <td id="T_84512_row10_col1" class="data row10 col1" > 수지체육공원</td>
#       <td id="T_84512_row10_col2" class="data row10 col2" > 도미너스FC</td>
#       <td id="T_84512_row10_col3" class="data row10 col3" > 8대5</td>
#       <td id="T_84512_row10_col4" class="data row10 col4" > 승</td>
#     </tr>
#     <tr>
#       <td id="T_84512_row11_col0" class="data row11 col0" >2022년 04월 08일(금)</td>
#       <td id="T_84512_row11_col1" class="data row11 col1" > 수지체육공원</td>
#       <td id="T_84512_row11_col2" class="data row11 col2" > 비틀즈FC</td>
#       <td id="T_84512_row11_col3" class="data row11 col3" > 3대3</td>
#       <td id="T_84512_row11_col4" class="data row11 col4" > 무</td>
#     </tr>
#     <tr>
#       <td id="T_84512_row12_col0" class="data row12 col0" >2022년 04월 16일(토)</td>
#       <td id="T_84512_row12_col1" class="data row12 col1" > 상현레스피아</td>
#       <td id="T_84512_row12_col2" class="data row12 col2" > 기쁨의교회</td>
#       <td id="T_84512_row12_col3" class="data row12 col3" > 8대1</td>
#       <td id="T_84512_row12_col4" class="data row12 col4" > 승</td>
#     </tr>
#     <tr>
#       <td id="T_84512_row13_col0" class="data row13 col0" >2022년 04월 23일(토)</td>
#       <td id="T_84512_row13_col1" class="data row13 col1" > 기흥레스피아</td>
#       <td id="T_84512_row13_col2" class="data row13 col2" > SG FC</td>
#       <td id="T_84512_row13_col3" class="data row13 col3" > 6대2</td>
#       <td id="T_84512_row13_col4" class="data row13 col4" > 패</td>
#     </tr>
#     <tr>
#       <td id="T_84512_row14_col0" class="data row14 col0" >2022년 04월 30일(토)</td>
#       <td id="T_84512_row14_col1" class="data row14 col1" > 기흥레스피아</td>
#       <td id="T_84512_row14_col2" class="data row14 col2" > 도미너스FC</td>
#       <td id="T_84512_row14_col3" class="data row14 col3" > 4대4</td>
#       <td id="T_84512_row14_col4" class="data row14 col4" > 무</td>
#     </tr>
#     <tr>
#       <td id="T_84512_row15_col0" class="data row15 col0" >2022년 03월 05일(토)</td>
#       <td id="T_84512_row15_col1" class="data row15 col1" > 기흥레스피아</td>
#       <td id="T_84512_row15_col2" class="data row15 col2" > G.O FC</td>
#       <td id="T_84512_row15_col3" class="data row15 col3" > 2대2</td>
#       <td id="T_84512_row15_col4" class="data row15 col4" > 무</td>
#     </tr>
#     <tr>
#       <td id="T_84512_row16_col0" class="data row16 col0" >2022년 03월 12일(토)</td>
#       <td id="T_84512_row16_col1" class="data row16 col1" > 기흥레스피아</td>
#       <td id="T_84512_row16_col2" class="data row16 col2" > 도미너스FC</td>
#       <td id="T_84512_row16_col3" class="data row16 col3" > 5대3</td>
#       <td id="T_84512_row16_col4" class="data row16 col4" > 패</td>
#     </tr>
#     <tr>
#       <td id="T_84512_row17_col0" class="data row17 col0" >2022년 03월 19일(토)</td>
#       <td id="T_84512_row17_col1" class="data row17 col1" > 기흥레스피아</td>
#       <td id="T_84512_row17_col2" class="data row17 col2" > 아미FC</td>
#       <td id="T_84512_row17_col3" class="data row17 col3" > 3대3</td>
#       <td id="T_84512_row17_col4" class="data row17 col4" > 무</td>
#     </tr>
#     <tr>
#       <td id="T_84512_row18_col0" class="data row18 col0" >2022년 03월 26일(토)</td>
#       <td id="T_84512_row18_col1" class="data row18 col1" > 수지체육공원</td>
#       <td id="T_84512_row18_col2" class="data row18 col2" > 비틀즈FC</td>
#       <td id="T_84512_row18_col3" class="data row18 col3" > 6대0</td>
#       <td id="T_84512_row18_col4" class="data row18 col4" > 승</td>
#     </tr>
#     <tr>
#       <td id="T_84512_row19_col0" class="data row19 col0" >2022년 02월 04일(금)</td>
#       <td id="T_84512_row19_col1" class="data row19 col1" > 기흥레스피아</td>
#       <td id="T_84512_row19_col2" class="data row19 col2" > 브록FC</td>
#       <td id="T_84512_row19_col3" class="data row19 col3" > 10대1</td>
#       <td id="T_84512_row19_col4" class="data row19 col4" > 패</td>
#     </tr>
#     <tr>
#       <td id="T_84512_

# %%
f = open('../data/gameRecord.txt','r',encoding='UTF8')
lines = f.readlines()
f.close()
lines
# Out:
# ['<2022년 07월 일정>\n',
#  '07월 02일(토) 기흥레스피아(아미FC / 8대4 승)\n',
#  '07월 09일(토) 기흥레스피아(BD99 FC / 4대3 패)\n',
#  '07월 16일(토) 구장없음\n',
#  '07월 23일(토) 기흥레스피아(도미너스FC / 6대4 승)\n',
#  '07월 30일(토) 기흥레스피아A 20-22(vs 영장FC)\n',
#  '\n',
#  '<2022년 06월 일정>\n',
#  '06월 04일(토) 기흥레스피아(개발FC / 4대2 패)\n',
#  '06월 10일(금) 매치 취소(인원 부족)\n',
#  '06월 18일(토) 기흥레스피아(YSI FC / 7대2 승)\n',
#  '06월 25일(토) 기흥레스피아(빌드어스FC / 8대5? 승)\n',
#  '\n',
#  '<2022년 05월 일정>\n',
#  '05월 07일(토) 기흥레스피아(위원FC / 8대4 승)\n',
#  '05월 14일(토) 기흥레스피아(비틀즈FC / 4대4 무)\n',
#  '05월 20일(금) 팬서스 회식\n',
#  '05월 21일(토) 동탄여울공원(DS FC / 7대1 승)\n',
#  '05월 28일(토) 수지체육공원(도미너스FC / 8대5 승)\n',
#  '\n',
#  '<2022년 04월 일정>\n',
#  '04월 02일(토) 홍민 결혼식\n',
#  '04월 08일(금) 수지체육공원(비틀즈FC / 3대3 무)\n',
#  '04월 16일(토) 상현레스피아(기쁨의교회 / 8대1 승)\n',
#  '04월 23일(토) 기흥레스피아(SG FC / 6대2 패)\n',
#  '04월 30일(토) 기흥레스피아(도미너스FC / 4대4 무)\n',
#  '\n',
#  '<2022년 03월 일정>\n',
#  '03월 05일(토) 기흥레스피아(G.O FC / 2대2 무)\n',
#  '03월 12일(토) 기흥레스피아(도미너스FC / 5대3 패)\n',
#  '03월 19일(토) 기흥레스피아(아미FC / 3대3 무)\n',
#  '03월 26일(토) 수지체육공원(비틀즈FC / 6대0 승)\n',
#  '\n',
#  '<2022년 02월 일정>\n',
#  '02월 04일(금) 기흥레스피아(브록FC / 10대1 패)\n',
#  '02월 12일(토) 기흥레스피아(그로FC / 3대3 무)\n',
#  '02월 19일(토) 기흥레스피아(G.O FC / 4대3 승)\n',
#  '02월 26일(토) 기흥레스피아C(크로우FC / 3대1 패)\n',
#  '\n',
#  '<2022년 01월 일정>\n',
#  '01월 01일(토) 기흥레스피아(DS FC / 7대1 승)\n',
#  '01월 04일(화) 기흥레스피아(???? / ?대? 패)\n',
#  '01월 08일(토) 기흥레스피아(G.O FC / 5대1 승)\n',
#  '01월 15일(토) 기흥레스피아(위원FC / 6대6 무)\n',
#  '01월 22일(토) 휴식(구장 없음)\n',
#  '01월 29일(토) 기흥레스피아(위원FC / 4대3 승)\n',
#  '\n',
#  '<2021년 12월 일정>\n',
#  '12월 04일(토) 기흥레스피아(G.O FC / 2대2 무)\n',
#  '12월 11일(토) 기흥레스피아(위원 FC / 5대5 무)\n',
#  '12월 18일(토) 기흥레스피아(아미 FC / 5대5 무)\n',
#  '12월 26일(일) 구장 없음\n',
#  '\n',
#  '<2021년 11월 일정>\n',
#  '11월 06일(토) 기흥레스피아(농협 FC / ?대? 승)\n',
#  '11월 13일(토) 기흥레스피아(slarva FC / 6대3 승)\n',
#  '11월 20일(토) 기흥레스피아(조인트 FC / ?대? 승)\n',
#  '11월 27일(토) 기흥레스피아(위원 FC / 6대4 패)\n',
#  '\n',
#  '<2021년 07월 일정>\n',
#  '07월 03일(토) 기흥레스피아(아미FC / 4대3 승)\n',
#  '07월 10일(토) 기흥레스피아(빌드어스FC / 4대2 패)\n',
#  '07월 17일(토) 기흥레스피아(GOP FC/ 7대2 승)\n',
#  '07월 23일(금) 기흥레스피아(SITE FC / 5대4 승)\n',
#  '07월 31일(토) 구장 사용불가(거리두기 4단계)\n',
#  '\n',
#  '<2021년 06월 일정>\n',
#  '06월 05일(토) 기흥레스피아(빌드어스FC / 1대1 무)\n',
#  '06월 12일(토) 기흥레스피아(기쁨의교회 / 5대1 승)\n',
#  '06월 19일(토) 기흥레스피아(자체전 / 수한팀 승)\n',
#  '06월 26일(토) 매치없음\n',
#  '\n',
#  '<2021년 05월 일정>\n',
#  '05월 01일(토) 기흥레스피아(불곡미스FC / 5대2 패)\n',
#  '05월 05일(수) 기흥레스피아(무제FC / 7대4 승)\n',
#  '05월 08일(토) 기흥레스피아(위원FC / 4대3 승) \n',
#  '05월 15일(토) 기흥레스피아(쪼인트 / 12대4 승)\n',
#  '05월 29일(토) 기흥레스피아(무제FC / 9대0 승)\n',
#  '\n',
#  '<2021년 04월 일정>\n',
#  '04월 03일(토) 기흥레스피아(WSC FC / 5대1 패)\n',
#  '04월 10일(토) 상현레스피아(위원FC / 4대4 무)\n',
#  '04월 17일(토) 기흥레스피아(MFC / 2대1 승)\n',
#  '04월 24일(토) 기흥레스피아(MFC, 89FC / 2승1무4패)\n',
#  '\n',
#  '<2021년 03월 일정>\n',
#  '03월 06일(토) 죽전아르피아(우노FC / 4대6 패)\n',
#  '03월 13일(토) 기흥레스피아(MFC / 7대6 승)\n',
#  '03월 20일(토) 기흥레스피아(위원FC / 3대3 무)\n',
#  '03월 27일(토) 기흥레스피아(MFC / 11대5 승)\n',
#  '\n',
#  '<2021년 02월 일정>\n',
#  '02월 20일(토) 기흥레스피아(킹스FC / 4대3 승)\n',
#  '02월 27일(토) 기흥레스피아(위원FC / 6대1 승)\n',
#  '\n',
#  '<2020년 12월 일정>\n',
#  '12월 05일 기흥레스피아(vs 제니스FC / 10대6 패)\n',
#  '\n',
#  '<2020년 11월 일정>\n',
#  '11월 07일(토) 풋살 자체전\n',
#  '11월 14일(토) 기흥레스피아(위원FC / 7대5 패)\n',
#  '11월 21일(토) 풋살 자체전\n',
#  '11월 28일(토) 기흥 레스피아(위원FC / ?)\n',
#  '\n',
#  '<2020년 10월 일정>\n',
#  '10월 31일(토) 기흥레스피아(위원FC / 8대1 승)\n',
#  '\n',
#  '<2020년 08월 일정>\n',
#  '08월 01일(토) 기흥레스피아(위원FC, 한보라FC)\n',
#  '08월 08일(토) 기흥레스피아(한마음FC / 6대3 승)\n',
#  '08월 15일(토) 기흥레스피아(한마음FC / 5대3 승)\n',
#  '08월 22일(토) 기흥레스피아(한마음FC / 4대4 무)\n',
#  '\n',
#  '<2020년 07월 일정>\n',
#  '07월 25일(토) 기흥레스피아(위원FC / 6대4 승)\n',
#  '\n',
#  '<2020년 04월 일정>\n',
#  '04월 25일(토) 기흥레스피아(위원FC / 4대2 패)\n',
#  '\n',
#  '<2020년 02월 일정>\n',
#  '02월 01일 (토) 기흥레스피아(라온FC / 11대4 승)\n',
#  '02월 08일 (토) 기흥레스피아(기쁨의교회 / 11대3승)\n',
#  '02월 15일 (토) 기흥레스피아(위원FC / 4대2 승)\n',
#  '\n',
#  '<2020년 01월 일정>\n',
#  '01월 04일(토) 용인종합(기쁨의교회FC / 4대3승)\n',
#  '01월 11일(토) 기흥레스피아(매스큘린FC / 6대3 패)\n',
#  '01월 18일(토) 기흥레스피아(기쁨의교회FC / 7대2승)\n',
#  '\n',
#  '<2019년 12월 일정>\n',
#  '12월 07일(토) 기흥레스피아(위원FC / 9대3 승)\n',
#  '12월 14일(토) 용인종합운동장(한숲FC / 6대5 승)\n',
#  '12월 21일(토) 기흥레스피아(한마음FC / 5대3 승)\n',
#  '12월 28일(토) 죽전 아르피아(우리들FC / 5대4 패)\n',
#  '\n',
#  '<2019년 11월 일정>\n',
#  '11월 02일(토) 용인 종합운동장(위원FC / 3대3 무)\n',
#  '11월 09일(토) 모현 레스피아(비비탄FC / 4대10 패)\n',
#  '11월 16일(토) 성남 종합운동장(아틸러리FC / 5대3 승)\n',
#  '11월 23일(토) 매치 취소(인원 부족)\n',
#  '11월 30일(토) 광주광남체육공원(우리들FC / 5대2 패)']
