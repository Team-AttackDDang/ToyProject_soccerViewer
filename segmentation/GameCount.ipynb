# %%
import pandas as pd 
df = pd.read_table('../data/gameRecord.txt', sep=',', header=None, names=['날짜', '장소','상대팀','점수','결과'])

for i in df['장소']:  
    if i != ' 구장없음':
        print(i)
# Out:
#  동탄여울공원
#  기흥레스피아
#  동탄여울공원
#  기흥레스피아
#  기흥레스피아
#  기흥레스피아
#  기흥레스피아
#  기흥레스피아
#  기흥레스피아
#  매치 취소
#  기흥레스피아
#  기흥레스피아
#  기흥레스피아
#  기흥레스피아
#  팬서스 회식
#  동탄여울공원
#  수지체육공원
#  홍민 결혼식
#  수지체육공원
#  상현레스피아
#  기흥레스피아
#  기흥레스피아
#  기흥레스피아
#  기흥레스피아
#  기흥레스피아
#  수지체육공원
#  기흥레스피아
#  기흥레스피아
#  기흥레스피아
#  기흥레스피아
#  기흥레스피아
#  기흥레스피아
#  기흥레스피아
#  기흥레스피아
#  휴식(구장 없음)
#  기흥레스피아
#  기흥레스피아
#  기흥레스피아
#  기흥레스피아
#  구장 없음
#  기흥레스피아
#  기흥레스피아
#  기흥레스피아
#  기흥레스피아
#  기흥레스피아
#  기흥레스피아
#  기흥레스피아
#  기흥레스피아
#  구장 사용불가
#  기흥레스피아
#  기흥레스피아
#  기흥레스피아
#  매치없음
#  기흥레스피아
#  기흥레스피아
#  기흥레스피아
#  기흥레스피아
#  기흥레스피아
#  기흥레스피아
#  상현레스피아
#  기흥레스피아
#  기흥레스피아
#  죽전아르피아
#  기흥레스피아
#  기흥레스피아
#  기흥레스피아
#  기흥레스피아
#  기흥레스피아
#  기흥레스피아
#  풋살 자체전
#  기흥레스피아
#  풋살 자체전
#  기흥 레스피아
#  기흥레스피아
#  기흥레스피아
#  기흥레스피아
#  기흥레스피아
#  기흥레스피아
#  기흥레스피아
#  기흥레스피아
#  기흥레스피아
#  기흥레스피아
#  기흥레스피아
#  용인종합운동장
#  기흥레스피아
#  기흥레스피아
#  기흥레스피아
#  용인종합운동장
#  기흥레스피아
#  죽전아르피아
#  용인종합운동장
#  모현레스피아
#  성남종합운동장
#  매치 취소
#  광주광남체육공원
